# %%
import numpy as np
import random
import itertools
import librosa
import IPython.display as ipd
import soundfile as sf

# %%
def load_audio_file(file_path):
    input_length = 16000
    data = librosa.core.load(file_path)[0] #, sr=16000
    if len(data)>input_length:
        data = data[:input_length]
    else:
        data = np.pad(data, (0, max(0, input_length - len(data))), "constant")
    return data

# %%
data2 = load_audio_file("/home/sayed/corpus/cmu_kids/kids/fabm/signal/fabm2al1.wav")
data, sr = librosa.load("/home/sayed/corpus/cmu_kids/kids/fabm/signal/fabm2al1.wav",sr=None)
ipd.Audio(data, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(data2,rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data_roll = np.roll(data, 1600)#
ipd.Audio(data_roll, rate=16000)

augmented_data = np.array(data_roll,dtype=np.float32)

if len(augmented_data.shape) >1:
    augmented_data= augmented_data.flatten()

sf.write("fabm2all_timeshift.wav", augmented_data,16000)

# %%
#loading lists

with open("/home/sayed/espnet/egs/CHILD_ASR/LISTS/in_child_wav.list","r") as org_file:
    org_items = [line.strip() for line in org_file if line.strip()]

with open("/home/sayed/espnet/egs/CHILD_ASR/LISTS/out_child_wav_timeshift.list","r") as timeshift_file:
    timeshift_items = [line.strip() for line in timeshift_file if line.strip()]

# %%
for i in range(len(org_items)):
    data, sr = librosa.load(org_items[i],sr=None)

    data_roll = np.roll(data, 1600)#
    
    augmented_data = np.array(augmented_data,dtype=np.float32)

    if len(augmented_data.shape) >1:
      augmented_data = augmented_data.flatten()

    sf.write(timeshift_items[i],augmented_data,16000)
